# %% [markdown]
# # Mitochondrial Diseases: ATP Synthase 6
#
#
#
# ## Introduction
#
# ATP synthase 6 (subunit 6) is located in the inner mitochondrial membrane and is important for forming the proton channel that drives ATP formation.  In this module, you will learn about the gene for ATP synthase 6 and how this protein is involved in human disease.  The subunit 6 of ATP synthase is the subunit that forms the transmembrane domain of ATP synthase (also referred to as subunit c which forms the proton channel, F$_{0}$).

# %% [markdown]
# You can review with the following book section.

# %% [markdown]
# **To view the reading, click on the next cell and hit SHIFT+ENTER on your keyboard**

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1GRE-fJerQLSvqYoe-Kq9RyNo3q3c5Wtx/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1GRE-fJerQLSvqYoe-Kq9RyNo3q3c5Wtx/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Objectives
#
# In this project, you will:
#
# * Research the ATP synthase using a patient's mDNA sequence and determine what is wrong (if anything) with the synthase of the patient. The patient has been showing symptoms for a mitochondrial disease as described in the readings below.
#
# * Analyze the mutant protein using bioinformatics tools within Google Colab.
#
# * Investigate the structure of the protein, model the mutation, and find out what is known, if anything, about the biological impact of the mutation.
#
# * Form a hypothesis about what the structural and biological effects are of this mutation.
#
# * Organize the results of your research into a report which you will present at the end of the semester.

# %% [markdown]
# ## Reading #1:
# ## Mitochondrial Disease:
#
# This first article was chosen to give you an overview of mitochondrial diseases.
#
# REF:
# * Wallace, D., “Mitochondrial DNA in Aging and Disease” Scientific American,
# Aug. (1997), p. 40 – 47.

# %% [markdown]
# Read pages 40-44.

# %%
IFrame('https://drive.google.com/file/d/11KKX0TvyXMSOutDz-PgVawg8gtGoOACI/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/11KKX0TvyXMSOutDz-PgVawg8gtGoOACI/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions.
#
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. Briefly describe the composition of the mitochondrial genome including approximate size and types of gene products.

# %% [markdown]
# Answer here

# %% [markdown]
# 2. How are mitochondrial genes inherited?

# %% [markdown]
# Answer here

# %% [markdown]
# 3. Explain why a mitochondrial genetic defect may not affect the person until they are older.

# %% [markdown]
# Answer here

# %% [markdown]
# 4. Imagine you’re a neurologist and a patient comes to you with the following symptoms:
# > some loss of verbal skills and progessive loss of motor skills
#
# You do an MRI and find that there has been some degeneration of the basal
# ganglia.  What disease do you suspect your patient has?

# %% [markdown]
# Answer here
