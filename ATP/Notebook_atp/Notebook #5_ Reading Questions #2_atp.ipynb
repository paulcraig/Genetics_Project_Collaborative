# %% [markdown]
# # Reading #2
#
# These readings provide you with some background in working with the crystal structure of ATP synthase.  The first article contains the crystal structure you will be studying.
#
# REF:
# * Rastogi, V.K., Girvin, M.E., Nature, vol. 402, pp. 263 (1999).
# * Nicholson, D., “Metabolic Minimap:  Mitochondrial ATP Formation,” Biochemistry and Molecular Biology Education, Vol 30 (1), p. 3 – 5 (2002).

# %% [markdown]
# **To view the reading, click on the next cell and hit SHIFT+ENTER on your keyboard**

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/18GAxeL3XlqzzlRUsonRqORB0KKu6znub/preview', width=600, height=300)

# %% [markdown]
# ## Answer the following questions:
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. What is the main point the authors of this paper are trying to make with the data presented in this article?

# %% [markdown]
# Answer here

# %% [markdown]
# 2. Draw a schematic view of Figure 1 and indicate the location of ATP synthase.

# %% [markdown]
# Answer here

# %% [markdown]
# 3. What would you predict would occur at the molecular level in a Asp61Gly mutation in ATP synthase 6?

# %% [markdown]
# Answer here

# %% [markdown]
# **To view the reading, click on the next cell and hit SHIFT+ENTER on your keyboard**

# %%
IFrame('https://drive.google.com/file/d/11KKX0TvyXMSOutDz-PgVawg8gtGoOACI/preview', width=600, height=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9ade83adcd46> in <module>()
# ----> 1 IFrame('https://drive.google.com/file/d/19VixHpFscwANOtrnPQbEDKFGVmqfmy0u/preview', width=600, height=300)
#
# NameError: name 'IFrame' is not defined

# %% [markdown]
# 4. Why is the mitochondrion referred to as the “powerhouse” of the cell?

# %% [markdown]
# Answer here

# %% [markdown]
# 5. How do Complexes I, III, and IV contribute to ATP formation in Complex V?

# %% [markdown]
# Answer here

# %% [markdown]
# 6. How is the structure and function of the F$_0$ subunit described in this article?

# %% [markdown]
# Answer here
