# %% [markdown]
# # Reading #2
#
# This reading provides you with some background in working with the crystal structure of the Ras protein.  The pages in Stryer provide some background about Ras proteins.  The article describes the experiment that gave the crystal structure you will be studying as well as how the authors interpreted the crystal structure data.
#
# REF:
# * Milburn, M.V., et al., “Molecular Switch…”, Science, Vol. 247, pp.
# 939, (1990).
# * Berg JM, Tymoczko JL, Stryer L, Clarke ND. Biochemistry. 5. ed., [Nachdr.], international ed. Freeman; 2003.

# %% [markdown]
# **To view the reading, click on the next cell and hit SHIFT+ENTER on your keyboard**

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1w5TcGR5NKGBojXsXidE9fU_NBI5rzAIY/preview', width=600, height=300)

# %% [markdown]
# ## Answer the following questions:
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. Where are the major structural differences between the GTP-bound and GDP bound forms of Ras?

# %% [markdown]
# Answer here

# %% [markdown]
# 2. How do the authors explain the interaction between Val at position 12 (Val$^{12}$) and the gamma phosphate of GDP-CP (the GTP analog)?

# %% [markdown]
# Answer here

# %% [markdown]
# 3. How does your answer to question 2 explain the increase in activated Ras of the Val 12 mutant?

# %% [markdown]
# Answer here

# %% [markdown]
# **To view the reading, click on the next cell and hit SHIFT+ENTER on your keyboard**

# %%
IFrame('https://drive.google.com/file/d/1h5izfduPvXOSZmWhJzQ0yOFKmmYTuBHi/preview', width=600, height=300)

# %% [markdown]
# 4. Explain the role of Ras in the epidermal growth factor (EDF) signalling pathway.

# %% [markdown]
# Answer here

# %% [markdown]
# 5. What are the three forms of Ras that mammalian cells contain?

# %% [markdown]
# Answer here
