# %% [markdown]
# # Cholesterol Homeostasis: HMG-CoA Reductase
#
# ## Introduction
#
# HMG-CoA Reductase is an enzyme in the cholesterol biosynthesis pathway.  It is the target of the family of statin drugs, which have become very important in the treatment of high cholesterol and reducing the risk for cardiovascular disease in many people.  In this module, you will learn about the gene for HMG-CoA reductase, how statins inhibit this enzyme, and how this enzyme is involved in cholesterol homeostasis.
#
# Many individuals who are currently taking statins have been diagnosed with “familial hypercholesterolemia”.  In this module, you will also be learning about this condition, its genetic basis, and why inhibition of HMG-CoA reductase is important to the treatment of this condition.

# %% [markdown]
# ## Objectives
#
# In this project, you will:
#
# * Examine a cDNA sequence froma patient that is completely unresponsive to statin therapy. This is highly unusual.  Normally serum cholesterol levels drop in response to statin therapy.
#
# * Analyze the mutant HMG protein using bioinformatics tools within Google Colab.
#
# * Investigate the structure of the HMG protein, model the mutation, and find out what is known, if anything, about the biological impact of the mutation.
#
# * Form a hypothesis about what the structural and biological effects are of this mutation; why the patient is not responding to statin therapy
#
# * Organize the results of your research into a report which you will present at the end of the semester.

# %% [markdown]
# ## Reading #1:
# ## Scientific American article: “Uncovering new clues to cancer risk”:
#
# The first set of readings is designed to give you an overview of the enzyme, statins, and their role in the prevention of coronary artery disease.
#
# REF:
# * Nabel, E.G., “Cardiovascular Disease”, N. Eng. J. Med., vol. 349, pp. 60-62.
# * Berg JM, Tymoczko JL, Stryer L, Clarke ND. Biochemistry. 5. ed., [Nachdr.], international ed. Freeman; 2003.

# %% [markdown]
# **Read until heading for “Hypertension” on page 62.**

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1loHZvW0lGR6OXEhz5hgirR0pCFY_u9Fe/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1loHZvW0lGR6OXEhz5hgirR0pCFY_u9Fe/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions.
#
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. How are LDLs cleared from the blood?

# %% [markdown]
# Answer here

# %% [markdown]
# 2. You’re a cardiologist who is treating a patient that has high serum cholesterol levels.   Your patient’s serum cholesterol level is 300 mg/dl.  You suspect your patient has familial hypercholesterolemia which affects 1 in 500 people.  Mutations in what gene is the cause of familial hypercholesterolemia?

# %% [markdown]
# Answer here

# %% [markdown]
# 3. Explain how PAH-DNA adducts can lead to cancer.

# %% [markdown]
# Answer here

# %% [markdown]
# 4. Mutations in what other genes have been found to result in elevated cholesterol?

# %% [markdown]
# Answer here

# %% [markdown]
# Read Sections 26.2.1 and 26.3.6

# %%
IFrame('https://drive.google.com/file/d/1YFUQR9XGeLnIUTF8hkKcPHW5vcH5mggl/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1YFUQR9XGeLnIUTF8hkKcPHW5vcH5mggl/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions.
#
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. What are the substrates for HMG-CoA reductase?

# %% [markdown]
# Answer here

# %% [markdown]
# 2. Briefly describe how statins work to lower serum cholesterol levels.

# %% [markdown]
# Answer here
