# %% [markdown]
# # Reading #2
#
# This set of readings provides you with some background in working with the crystal structure of HMG-CoA Reductase and its bound statin.  This article contains the crystal structure you will be studying.  Answer the questions and turn in your written answers at the third lab meeting.
#
# REF:
# * Istvan, E.S., and Deisenhofer, J., “Structural Mechanism for Statin Inhibition of HMG-CoA Reductase”, Science, vol. 292, pp. 1160 – 1164 (2001).
# * Berg JM, Tymoczko JL, Stryer L, Clarke ND. Biochemistry. 5. ed., [Nachdr.], international ed. Freeman; 2003.

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1mJTFcSwLTMqwhWNXn76uSISNece_hvXW/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1mJTFcSwLTMqwhWNXn76uSISNece_hvXW/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions:
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. Where on the protein does the statin molecule bind in relative to the substrate HMG?

# %% [markdown]
# Answer here

# %% [markdown]
# 2.  In Figure 4, in which of the structures was a hydrogen bond between Asp690 and the statin observed?

# %% [markdown]
# Answer here

# %% [markdown]
# Read Sections 26.3 and 26.3.5-26.4.1

# %%
IFrame('https://drive.google.com/file/d/1p8VHey5mMvq2IczeBFQFZYNCL70uqsMc/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1p8VHey5mMvq2IczeBFQFZYNCL70uqsMc/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# 4. What are the four ways that HMG-CoA reductase is controlled?

# %% [markdown]
# Answer here

# %% [markdown]
# 5. What is the difference in treatments for homozygous familial hypercholesterolemia and heterozygous familial hypercholesterolemia?

# %% [markdown]
# Answer here

# %% [markdown]
# 6. Name three types of molecules that are derived from cholesterol and a biological function for each.

# %% [markdown]
# Answer here
