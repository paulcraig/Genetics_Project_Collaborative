# %% [markdown]
# # Welcome to your Genetics Lab!
#
# This lab is designed around bioinformatics tools that are widely used in biomedical research today. Over the past few years, the number of freely available software programs and web-based research tools has increased dramatically. Knowing how to use these tools is very important to research and health professionals in order to access and interpret the constantly growing amounts of genomic and proteomic information. These bioinformatics tools as well as genomic information are freely available on
# the web to anyone who knows how to access them. This Lab introduces these computer-based research tools in a context that reinforces concepts in Genetics.
#
# During the lab sessions you will use computer programming in the environment of Google Colab to learn more about a specific genetic disease related to a gene of interest assigned to you.

# %% [markdown]
# ## Introduction to Colab!
#
# In order to complete your Genetics Lab Modules, you will need to learn how to navigate and use Google Colab.
#
# You will begin these Colab Notebooks with a series of exercises that will introduce you to coding in this environment.

# %%
# INSERT TUTORIAL HERE
  # Programming language - Python
  # Operations
  # Executing cells
  # Packages and modules
  # Syntax (int, string, tuple, etc)
  # Functions
  # Obtaining help and object types
  # Module, packages and imports
  # Object-oriented programming, attributes

# https://github.com/Nichole-png/scientific-python-lectures/blob/master/Lecture-1-Introduction-to-Python-Programming.ipynb
