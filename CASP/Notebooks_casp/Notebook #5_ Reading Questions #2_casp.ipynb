# %% [markdown]
# # Reading #2
#
# This set of readings provides you with some background in working with the crystal structure of caspase-1 and its bound tetrapeptide inhibitor.  The article listed below reports the crystal structure that you will be studying.  An excerpt from this article is on the course website for you to read.  The pages in Stryer are for you to review the mechanism of proteases, in specific, cysteine proteases.
#
# REF:
# * Rano, T. A., et al.,”A combinatorial approach…interleukin-1b converting enzyme (ICE),” Chem. Biol., vol. 4, no. 2, p. 149 – 155 (1997).
# * Berg JM, Tymoczko JL, Stryer L, Clarke ND. Biochemistry. 5. ed., [Nachdr.], international ed. Freeman; 2003.

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1w5TcGR5NKGBojXsXidE9fU_NBI5rzAIY/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1w5TcGR5NKGBojXsXidE9fU_NBI5rzAIY/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions:
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. Write the two tetrapeptide sequences using their three-letter codes:  WEHD and YVAD.

# %% [markdown]
# Answer here

# %% [markdown]
# 2. Which of the above peptides was preferred by ICE/caspase-1?

# %% [markdown]
# Answer here

# %% [markdown]
# 3. Describe the type of inhibition of ICE/caspase-1 seen with peptide aldehyde inhibitors.

# %% [markdown]
# Answer here

# %% [markdown]
# 4. What does the cagey-looking part of Figure 3 represent?

# %% [markdown]
# Answer here

# %% [markdown]
# ## Read sections 9.1.2 – 9.1.6

# %%
IFrame('https://drive.google.com/file/d/1lYX9tVbk-r8ArrXfJpSi8RNEsfDdK6Oh/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1lYX9tVbk-r8ArrXfJpSi8RNEsfDdK6Oh/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# 5. How is the nucleophilic attack the same with a cysteine protease (like caspase-1 or papain) and chymotrypsin?

# %% [markdown]
# Answer here

# %% [markdown]
# 6. Cysteine proteases have a His in the active site similar to the His of the catalytic triad in chymotrypsin (see Fig. 9.17).  What do you suppose would happen to enzyme activity if this His were mutated to an alanine?

# %% [markdown]
# Answer here
