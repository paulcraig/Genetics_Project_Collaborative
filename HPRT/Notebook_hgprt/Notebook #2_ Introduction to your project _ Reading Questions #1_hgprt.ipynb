# %% [markdown]
# # Metabolic Disease: Hypoxanthine-guanine phosphoribosyltransferase (HPRT)
#
# ## Introduction
#
# Metabolic disease is a broad term that is generally used to describe diseases that result from enzyme deficiencies in either catabolic or biosynthesis pathways.  When these enzyme deficiencies occur, there is not only a decrease in the products of the pathway, but the intermediates in the pathway also build up.  Symptoms of metabolic disease occur from one or both of these biochemical causes.  Often, the build-up and storage of the metabolic intermediates cause the major symptoms associated with these diseases.
#
# Lesch-Nyhan disease is a metabolic disease caused by a deficiency in the enzyme, hypoxanthine-guanine phosphoribosyltransferase (HPRT).  HPRT is an enzyme in the purine salvage pathway and when deficient, causes the metabolite, urate, to build up.  This build-up can cause kidney stones and gout.  Primary symptoms of Lesch-Nyhan disease include neurological problems such as mental deficiency and self-destructive
# behavior.

# %% [markdown]
# ## Objectives
#
# In this project, you will:
#
# * Analyze a cDNA sequence from a patient suspected to have Lesch-Nyhan Syndrome
#
# * Analyze the mutant HPRT protein using bioinformatics tools within Google Colab.
#
# * Investigate the structure of the HPRT protein, model the mutation, and find out what is known, if anything, about the biological impact of the mutation.
#
# * Form a hypothesis about what the structural and biological effects are of this mutation.
#
# * Organize the results of your research into a report which you will present at the end of the semester.

# %% [markdown]
# ## Reading #1:
# ## NCBI online text: “Nutritional and Metabolic Diseases”
#
# The first set of readings is designed to give you an overview of metabolic disease and Lesch-Nyhan syndrome (LNS).
#
# REF:
# * National Center for Biotechnology Information (US). Genes and Disease [Internet]. Bethesda (MD): National Center for Biotechnology Information (US); 1998-. Nutritional and Metabolic Diseases. Available from: https://www.ncbi.nlm.nih.gov/books/NBK22259/

# %% [markdown]
# Read pages 1-2 and page 10.

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1lH_zHJcXzXcZ7ibPpmW37iaP-uf-9cQn/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1lH_zHJcXzXcZ7ibPpmW37iaP-uf-9cQn/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions.
#
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. Briefly describe what is meant by the term, “metabolic disease.”

# %% [markdown]
# Answer here

# %% [markdown]
# 2. Do mutations in enzymes always result in metabolic disease?  Please explain.

# %% [markdown]
# Answer here

# %% [markdown]
# 3. Describe the symptoms associated with Lesch-Nyhan Syndrome (LNS).

# %% [markdown]
# Answer here

# %% [markdown]
# 4. What metabolite builds up in Lesch-Nyhan Syndrome?

# %% [markdown]
# Answer here
